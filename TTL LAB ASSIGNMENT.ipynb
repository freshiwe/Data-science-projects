# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
zomato=pd.read_csv(r"C:\Users\KIIT\Downloads\zomato.csv")
zomato.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
Automobile=pd.read_csv(r"C:\Users\KIIT\Downloads\Automobile.csv")
Automobile.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          205 non-null    int64
#  1   normalized_losses  164 non-null    float64
#  2   make               205 non-null    object
#  3   fuel_type          205 non-null    object
#  4   aspiration         205 non-null    object
#  5   num_doors          203 non-null    object
#  6   body_style         205 non-null    object
#  7   drive_wheels       205 non-null    object
#  8   engine_location    205 non-null    object
#  9   wheel_base         205 non-null    float64
#  10  length             205 non-null    float64
#  11  width              205 non-null    float64
#  12  height             205 non-null    float64
#  13  curb_weight        205 non-null    int64
#  14  engine_type        205 non-null    object
#  15  num_cylinders      205 non-null    object
# ...

# %%
Foodtruck=pd.read_csv(r"C:\Users\KIIT\Downloads\Foodtruck.csv")
Foodtruck.head()
# Out:
#    Population   Profit
# 0      6.1101  17.5920
# 1      5.5277   9.1302
# 2      8.5186  13.6620
# 3      7.0032  11.8540
# 4      5.8598   6.8233

# %%
student_scores=pd.read_csv(r"C:\Users\KIIT\Downloads\student_scores.csv")
student_scores.head()
# Out:
#    Hours  Scores
# 0    2.5      21
# 1    5.1      47
# 2    3.2      27
# 3    8.5      75
# 4    3.5      30

# %%
# Create a histogram for the 'Profit' column
plt.figure(figsize=(8, 6))
sns.histplot(data=Foodtruck, x='Profit', bins=20, kde=True, color='skyblue')
plt.title('Profit Distribution')
plt.xlabel('Profit')
plt.ylabel('Frequency')
plt.show()

# %%
# Calculating the average profit by population group (you can adjust this grouping as needed)
# Create a bar chart
plt.figure(figsize=(10, 6))
sns.barplot(data=student_scores, x='Hours', y='Scores', palette='viridis')
plt.title('Average Profit by Population Group')
plt.xlabel('Population')
plt.ylabel('Average Profit')
plt.xticks(rotation=45)
plt.show()

# %%
# Calculate the average profit by population group (you can adjust this grouping as needed)
# Create a bar chart
plt.figure(figsize=(10, 6))
sns.boxplot(data=student_scores)
plt.title('Box Plot showing student scores and Hours')
plt.ylabel('Values')
plt.xticks(rotation=45)
plt.show()

# %%
df=student_scores.corr()
sns.heatmap(df)
plt.show()

# %%
df1=zomato.corr()
sns.heatmap(df1)
plt.show()

# %%
import scipy.integrate as spi

def f(x):
    return x**2

result, _ = spi.quad(f, 0, 1)
print(f"Integral of x^2 from 0 to 1: {result:.4f}")
# Out:
# Integral of x^2 from 0 to 1: 0.3333

# %%
import numpy as np
from scipy.misc import derivative

def g(x):
    return np.sin(x)

derivative_at_pi_over_4 = derivative(g, np.pi/4, dx=1e-6)
print(f"Derivative of sin(x) at x = pi/4: {derivative_at_pi_over_4:.4f}")
# Out:
# Derivative of sin(x) at x = pi/4: 0.7071

# %%
from scipy.optimize import minimize

def h(x):
    return x**2 + 3*x + 5

result = minimize(h, x0=0)
print(f"Minimum value of h(x): {result.fun:.4f} at x = {result.x[0]:.4f}")
# Out:
# Minimum value of h(x): 2.7500 at x = -1.5000

# %%
import numpy as np
from scipy.linalg import solve

# Example system of equations: 2x + y = 5, 3x - 2y = 8
A = np.array([[2, 1], [3, -2]])
b = np.array([5, 8])

x = solve(A, b)
print(f"Solutions (x, y): ({x[0]:.4f}, {x[1]:.4f})")
# Out:
# Solutions (x, y): (2.5714, -0.1429)

# %%
from sklearn.datasets import load_iris

# Load the Iris dataset
iris = load_iris()

# Print the dataset description
print(iris.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Encode target labels
label_encoder = LabelEncoder()
iris_target_encoded = label_encoder.fit_transform(iris.target)

# Replace the original target labels with encoded values
iris.target = iris_target_encoded

# %%
import cv2

# Load an image from file
img = cv2.imread(r"C:\Users\KIIT\Downloads\business_2_18.png")

# Display the image in a window
cv2.imshow('Loaded Image', img)

# Wait for a key press to close the window
cv2.waitKey(0)

# Close all OpenCV windows
cv2.destroyAllWindows()

# %%
# Resize the image to a new width and height
new_width, new_height = 300, 200
resized_img = cv2.resize(img, (new_width, new_height))

# Display the resized image
cv2.imshow('Resized Image', resized_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Rotate the image by 45 degrees clockwise
angle = 45
rows, cols = resized_img.shape[:2]
rotation_matrix = cv2.getRotationMatrix2D((cols/2, rows/2), angle, 1)
rotated_img = cv2.warpAffine(resized_img, rotation_matrix, (cols, rows))

# Display the rotated image
cv2.imshow('Rotated Image', rotated_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Flip the image vertically
flipped_img = cv2.flip(rotated_img, 0)

# Display the flipped image
cv2.imshow('Flipped Image', flipped_img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt


# Convert BGR to RGB for display
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# Display the original image
plt.figure(figsize=(6, 6))
plt.imshow(img_rgb)
plt.title('Original Image')
plt.axis('off')
plt.show()

# %%
# Apply Gaussian blur
blurred_img = cv2.GaussianBlur(img, (5, 5), 0)

# Convert BGR to RGB for display
blurred_img_rgb = cv2.cvtColor(blurred_img, cv2.COLOR_BGR2RGB)

# Display the blurred image
plt.figure(figsize=(6, 6))
plt.imshow(blurred_img_rgb)
plt.title('Gaussian Blur')
plt.axis('off')
plt.show()

# %%
# Apply median blur
median_blurred_img = cv2.medianBlur(img, 5)

# Convert BGR to RGB for display
median_blurred_img_rgb = cv2.cvtColor(median_blurred_img, cv2.COLOR_BGR2RGB)

# Display the median-blurred image
plt.figure(figsize=(6, 6))
plt.imshow(median_blurred_img_rgb)
plt.title('Median Blur')
plt.axis('off')
plt.show()

# %%
import cv2


# Convert to grayscale
gray_image = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# Display the grayscale image
cv2.imshow('Grayscale Image', gray_image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Load the image in grayscale
gray_image_flag = cv2.imread(r"C:\Users\KIIT\Downloads\business_2_18.png", 0)

# Display the grayscale image
cv2.imshow('Grayscale Image (Flag=0)', gray_image_flag)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
# Convert to grayscale using pixel manipulation (average method)
(row, col) = img.shape[0:2]
for i in range(row):
    for j in range(col):
        img[i, j] = sum(img[i, j]) // 3

# Display the grayscale image
cv2.imshow('Grayscale Image (Pixel Manipulation)', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Apply Gaussian blur to reduce noise
blurred_image = cv2.GaussianBlur(img, (5, 5), 0)

# Apply Canny edge detection
edges = cv2.Canny(blurred_image, 30, 100)  # Adjust thresholds as needed

# Display the original image and its edges
plt.figure(figsize=(10, 5))
plt.subplot(121), plt.imshow(img, cmap='gray')
plt.title('Original Image'), plt.axis('off')
plt.subplot(122), plt.imshow(edges, cmap='gray')
plt.title('Edges (Canny)'), plt.axis('off')
plt.show()

# %%
# Find contours in the edges image
contours, _ = cv2.findContours(edges, cv2.RETR_EXTERNAL, cv2.CHAIN_APPROX_SIMPLE)

# Draw contours on the original RGB image
contour_image = img.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)  # Green color, thickness 2

# Display the image with contours
plt.figure(figsize=(6, 6))
plt.imshow(cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB))
plt.title('Contours Detected')
plt.axis('off')
plt.show()
